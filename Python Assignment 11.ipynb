# %% [markdown]
# Ques 1: Create an assert statement that throws an AssertionError if the variable spam is a negative integer.

# %% [markdown]
# Ans 1: assert spam >= 10, 'The spam variable less than 10'.

# %% [markdown]
# Ques 2: Write assert statement that triggers an AssertionError if the variables eggs and bacon contain strings that are the same as each other, even if their cases are different(that is,'hello' are considered the same, and 'goodbye' and 'GOODbye' are also considered the same).

# %% [markdown]
# Ans 2: assert eggs.lower() != bacon.lower(), 'The eggs and bacon variables are the same!' or assert eggs.upper() != bacon.upper(), 'The eggs and bacon variables are the same!'

# %% [markdown]
# Ques 3: Create an assert statement that throws an AssertionError every time.

# %% [markdown]
# Ans 3: assert False, 'This assertion always triggers.'

# %% [markdown]
# Ques 4: What are the two lines that must be present in your software in order to call logging.debug()?

# %% [markdown]
# Ans 4: To be able to call logging.debug(), you must have these two lines at the start of your program:

# %%
import logging
logging.basicConfig(level=logging.DEBUG,format='%(asctime)s-%(levelname)s-%(message)s')

# %% [markdown]
# Ques 5: What are the two lines that your program must have in order to have logging.debug() send a logging message to a file named programLog.txt?

# %% [markdown]
# Ans 5: To be able to send logging messages to a file named programLog.txt with logging.debug(), you must have these two lines at the start of your program:

# %%
import logging
logging.basicConfig(filename='program Log.txt',level=logging.DEBUG,format='%(asctime)s-%(levelname)s-%(message)s')

# %% [markdown]
# Ques 6: What are the five levels of logging?

# %% [markdown]
# Ans 6: DEBUG, INFO, WARNING, ERROR, and CRITICAL.

# %% [markdown]
# Ques 7: What line of code would you add to your software to disable all logging messages?

# %% [markdown]
# Ans 7: logging.disable(logging.CRITICAL)

# %% [markdown]
# Ques 8: Why is using logging messages better than using print() to display the same message?

# %% [markdown]
# Ans 8: You can disable logging messages without removing the logging function calls. You can selectively disable lower-level logging messages. You can create logging messages. Logging messages provides a timestamp.

# %% [markdown]
# Ques 9: What are the difference between the Step Over, Step In, and Step Out buttons in the debugger?

# %% [markdown]
# Ans 9: The Step button will move the debugger into a function call. The Over button will quickly execute the function call without stepping into it. The Out button will quickly execute the rest of the code until it steps out of the function it currently is in.

# %% [markdown]
# Ques 10: Afetr you click Continue, when will the debugger stop?

# %% [markdown]
# Ans 10: After you click Go, the debugger will stop when it has reached the end of the program or a line with a breakpoint.

# %% [markdown]
# Ques 11: What is the concept of a breakpoint?

# %% [markdown]
# Ans 11: A breakpoint is a setting on a line of code that causes the debugger to pause when the program execution reaches the line.
