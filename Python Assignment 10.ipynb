# %% [markdown]
# Ques 1: How do you distinguish between shutil.copy() and shutil.copytree()?

# %% [markdown]
# Ans 1: The shutil.copy() function will copy a single file, while shutil.copytree() will copy an entire folder, along with all its contents.

# %% [markdown]
# Ques 2: What function is used to rename files?

# %% [markdown]
# Ans 2: The shutil.move() function is used for renaming files, as well as moving them.

# %% [markdown]
# Ques 3: What is the difference between the delete functions in the send2trash and shutil modules?

# %% [markdown]
# Ans 3: The send2trash fucntions will move a fiele or folder to the recycle bin, while shutil functions will permanently delete files and folders.

# %% [markdown]
# Ques 4: ZipFile objects have a close() method just like File objects' close() method. What ZipFile method is equivalent to File objects' open() method?

# %% [markdown]
# Ans 4: The zipfile.ZipFile() function is equivalent to the open() function; the first argument is the filename, and the second argument is the mode to open the ZIP file in (read, write, or append).

# %% [markdown]
# Ques 5: Create a programme that searches a folder tree for files with a certain file exension (such as .pdf or .jpg). Copy these files from whatever location they are in to a new folder.

# %%
 def copyFile(src,dst,ext):
    try:
        import os,shutil
        for file in os.listdir(src):
            if file.endswith(ext):
                shutil.copy(os.path.join(src,file),dst)
        print(f'Files have been successfully copied from {src} to {dst}')
    except Exception as e:
        print(e)
        
copyFile(r'C:\Users\Khushboo Gaur\Downloads',r'C:\Users\Khushboo Gaur\Downloads','.pdf')
# Out:
# 'C:\\Users\\Khushboo Gaur\\Downloads\\InfosysCertificationExaminationGuidelines.pdf' and 'C:\\Users\\Khushboo Gaur\\Downloads\\InfosysCertificationExaminationGuidelines.pdf' are the same file
