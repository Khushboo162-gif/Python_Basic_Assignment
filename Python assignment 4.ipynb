# %% [markdown]
# Ques 1: What exactly is [] ?

# %% [markdown]
# Ans 1: The empty list value, which is a list value that contains no items. This is similar to how " is the empty string value.

# %% [markdown]
# Ques 2: In a list of values stored in a variable called spam, how would you assign the value 'hello' as the third value? (Assume [2,4,6,8,10] are in spam.)
#
# Let's pretend the spam icludes the list ['a','b','c','d'] for the next three queries.

# %% [markdown]
# Ans 2: spam[2] == 'hello' (Notice that the third value in alist is at index 2 because the first index is 0.)

# %% [markdown]
# Ques 3: What is the value of spam[int(int('3'*2)/11)] ?

# %% [markdown]
# Ans 3: 'd' (Note that '3'*2 is the string '33',which is passed to int() before being divided by 11. This eventually evaluates to 3.Expressions can be used wherever values are used.)

# %% [markdown]
# Ques 4: What is the value of spam[-1] ?

# %% [markdown]
# Ans 4: 'd' (Negative indexes count from the end.)

# %% [markdown]
# Ques 5: What is the value of spam[:2] ?
#
#     Let's pretend bacon has the list [3.14,'cat',11,'cat',True] for the next three questions.

# %% [markdown]
# Ans 5: ['a','b']

# %% [markdown]
# Ques 6: What is the value of bacon.index('cat') ?

# %% [markdown]
# Ans 6: 1

# %% [markdown]
# Ques 7: How does bacon.append(99) change the look of the list value in bacon ?

# %% [markdown]
# Ans 7: [3.14,'cat',11,'cat',True,99]

# %% [markdown]
# Ques 8: How does bacon.remove('cat') change the look of the list in bacon ?

# %% [markdown]
# Ans 8: [3.14,11,'cat',True]

# %% [markdown]
# Ques 9: What are the list concatenation and list replication operators?

# %% [markdown]
# Ans 9: The operator for list concatenation is +,while the operator for replication is *.(This is the same as for strings.)

# %% [markdown]
# Ques 10: What is the difference between the list methods append() and insert() ?

# %% [markdown]
# Ans 10: While append() will add values only to the end of a list,insert() can add them anywhere in the list

# %% [markdown]
# Ques 11: What are the two methods for removing items from a list?

# %% [markdown]
# Ans 11: The del statement and the remove() list method are two ways to remove values from a list.

# %% [markdown]
# Ques 12: Describe how list values and string values are identical?

# %% [markdown]
# Ans 12: Both lists and strings can be passed to len(),have indexes and slices, be used in for loops,be concatenated or replicated,and be used with the in and not in operators.

# %% [markdown]
# Ques 13: What's the difference between tuples and lists?

# %% [markdown]
# Ans 13: Lists are nutable;they can have values added, removed,or changed. Tuples are immutable; they cannot be changed at all. Also, tuples are written using parentheses, (and), while lists use the square brackets,[and]

# %% [markdown]
# Ques 14: How do you type a tuple value that only contains the integer 42?

# %% [markdown]
# Ans 14: (42,) (The trailing comma is mandatory.)

# %% [markdown]
# Ques 15: Howdo you get a list value's tuple form? How do you get a tuple value's list from?

# %% [markdown]
# Ans 15: The tuple() and list() functions,respectively.

# %% [markdown]
# Ques 16: Variables that "contain" list values are not necessarily lists themselves. Instead, what do they contain?

# %% [markdown]
# Ans 16: They contain references to list values.

# %% [markdown]
# Ques 17: How do you distinguish between copy.copy() and copy.deepcopy()?

# %% [markdown]
# Ans 17: The copy.copy() function will do a shallow copy of a list, while the copy.deepcopy() function will do a deep copy of a list.That is, only copy.deepcopy() will duplicate any lists inside the list.
