# %% [markdown]
# Ques 1: What is the difference between enclosing a list comprehension in square brackets and parentheses?

# %% [markdown]
# Ans 1: sqauare bracket is list and parentheses is tuple

# %% [markdown]
# Ques 2: What is the relationship between generators and iterators?

# %% [markdown]
# Ans 2: Every generator is an iterator.

# %% [markdown]
# Ques 3: What are the signs that a function is a generator function?

# %% [markdown]
# Ans 3: Function must contain yield statement.

# %% [markdown]
# Ques 4: What is the purpose of a yield statement?

# %% [markdown]
# Ans 4: yield has same purpose as return except it returns value one by one. This is very useful when we need to return huge number of values.

# %% [markdown]
# Ques 5: What is the relationship between map calls and list comprehensions? Make a comparison and contrast between the two.

# %% [markdown]
# Ans 5: If we have to use same operation for each item in a sequence of iterable, then both are useful.
#
# comparison:
#
# 1.We can filter in list comprehension but it is not possible for map calls.
#
# 2.list comprehension is used when list of result is required but map only returns map object not list.
