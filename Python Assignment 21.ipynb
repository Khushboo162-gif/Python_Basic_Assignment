# %% [markdown]
# 1: Add the current data to the text file today.txt as a string.

# %%
import datetime
date = str(datetime.datetime.now().date())
with open('today.txt','w') as f:
    f.write(date)

# %% [markdown]
# 2: Read the text file today.txt into the string today_string

# %%
with open('today.txt','r') as f:
    today_string = f.read()

# %% [markdown]
# 3: Parse the data from today_string.

# %%
today_string
# Out:
# '2022-03-20'

# %% [markdown]
# 4: List files in your current directory.

# %%
import os
list_dir = os.listdir()
list_dir
# Out:
# ['.azuredatastudio',
#  '.idlerc',
#  '.ipynb_checkpoints',
#  '.ipython',
#  '.jupyter',
#  '.matplotlib',
#  '3D Objects',
#  'adult.csv',
#  'Advertising.csv',
#  'anaconda3',
#  'AppData',
#  'Application Data',
#  'books.csv',
#  'books.db',
#  'cache',
#  'catboost_info',
#  'Contacts',
#  'Cookies',
#  'data_description (1).txt',
#  'data_description.txt',
#  'DBSCAN.ipynb',
#  'Documents',
#  'Downloads',
#  'Favorites',
#  'formulatedtest.csv',
#  'House prices(handle test data).ipynb',
#  'Housing Prices (EDA).ipynb',
#  'image.jpg',
#  'Ineuron questions.ipynb',
#  'IntelGraphicsProfiles',
#  'Kaggle Competition for House Prices.ipynb',
#  'kaggle train.ipynb',
#  'KMeans.ipynb',
#  'Links',
#  'Local Settings',
#  'Mall_Customers.csv',
#  'MicrosoftEdgeBackups',
#  'Music',
#  'My Documents',
#  'NetHood',
#  'NTUSER.DAT',
#  'ntuser.dat.LOG1',
#  'ntuser.dat.LOG2',
#  'NTUSER.DAT{1c2b59c6-c5f5-11eb-bacb-000d3a96488e}.TM.blf',
# ...

# %% [markdown]
# 5: Create a list of all the files in your parent directory(minimum five files should be available).

# %%
parent_dir = os.listdir('..')
parent_dir
# Out:
# ['All Users',
#  'Default',
#  'Default User',
#  'desktop.ini',
#  'Khushboo Gaur',
#  'Public']

# %% [markdown]
# 6: Use multiprocessing to create three separate processes. Make each one wait a random number of seconds between one and five, print the current time, and then exit.

# %%
#multi.py
# import multiprocessing
# from random import randint
# def wait(seconds):
#     from datetime import datetime
#     from time import sleep
#     print(f'wait {seconds} seconds')
#     sleep(seconds)
#     print('current time: ', datetime.now().time())
    
# if __name__ == "__main__":
#     for i in range(3):
#         from random import randint
#         seconds=randint(1,5)
#         p=multiprocessing.Process(target=wait, args=(seconds,))
#         p.start()

# %%
# !python multi.py

# %% [markdown]
# 7: Create a data object of your day of birth.

# %%
from datetime import datetime
bday=datetime(2000,7,25)

# %% [markdown]
# 8: What day of the week was your day of birth?

# %%
bday.strftime("%A")
# Out:
# 'Tuesday'

# %% [markdown]
# 9: When will you be (or when were you) 10,000 days old?

# %%
from datetime import timedelta
days=timedelta(days=10000)
str(bday.date()+days)
# Out:
# '2027-12-11'
