# %% [markdown]
# Qus 1: What advantages do Excel spreadsheets have over CSV spreadsheets?

# %% [markdown]
# Ans 1: In Excel, spreadsheets can have values of data types other than strings; cells can have different fonts, sizes, or color settings; cells can have varying widths and heights; adjacent cells can be merged; and you can embed images and charts.

# %% [markdown]
# Ques 2: What do you pass to csv.reader() and csv.writer() to create reader and writer objects?

# %% [markdown]
# Ans 2: You pass a File object, obtained from a call to open().

# %% [markdown]
# Ques 3: What modes do File objects for reader and writer objects need to be opened in?

# %% [markdown]
# Ans 3: File objects need to be opened in read-binary('rb') for Reader objects and write-binary('wb') for Writer objects.

# %% [markdown]
# Ques 4: What method takes a list argument and writes it to a CSV file?

# %% [markdown]
# Ans 4: The writerow() method.

# %% [markdown]
# Ques 5: What do the keyword arguments delimiter and line terminator do?

# %% [markdown]
# Ans 5: The delimiter argument changes the string used to seperate cels in a row. The lineterminator argument changes the string used to separate rows.

# %% [markdown]
# Ques 6: What function takes a string of JSON data and returns a Python data structure?

# %% [markdown]
# Ans 6: json.loads()

# %% [markdown]
# Ques 7: What function takes a Python data structure and returns a string of JSON data?

# %% [markdown]
# Ans 7: json.dumps()
