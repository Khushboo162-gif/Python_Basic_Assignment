# %% [markdown]
# Ques 1: To what does a relative path refer?

# %% [markdown]
# Ans 1: Relative paths are relative to the current working directory.

# %% [markdown]
# Ques 2: What does an absolute path start with your operating system?

# %% [markdown]
# Ans 2: Absolute paths start with the root folder, such as / or C: \ .

# %% [markdown]
# Ques 3: What does the functions os.getcwd() and os.chdir() do?

# %% [markdown]
# Ans 3: The os.getcwd() function returns the current working directory. The os,chdir() function changes the current working directory.

# %% [markdown]
# Ques 4: What are the . and .. folders?

# %% [markdown]
# Ans 4: The . folder is the current folder, and .. is the parent folder.

# %% [markdown]
# Ques 5: In C:\bacon\eggs\spam.txt, which part is the dir name, and which part is the base name?

# %% [markdown]
# Ans 5: C:\bacon\eggs is the dir name, while spam.txt is the base name.

# %% [markdown]
# Ques 6: What are the three "mode" arguments that can be passed to the open() function?

# %% [markdown]
# Ans 6: The string 'r' for read mode, 'w' for write mode, and 'a' for append mode.

# %% [markdown]
# Ques 7: What happens if an existing file is opened in write mode?

# %% [markdown]
# Ans 7: An existing file opened in write mode is erased and completely overwritten.

# %% [markdown]
# Ques 8: How do you tell the difference between read() and readlines()?

# %% [markdown]
# Ans 8: The rea() method returns the file's entire contents as a single string value. The readlines() method returns a list of strings, where each string is a line from the file's contents.

# %% [markdown]
# Ques 9: What data structure does a shelf value resemble?

# %% [markdown]
# Ans 9: A shelf value resembles a dictionary value; it has keys and values, along with keys() and values() methods that work similarly to the dictionary mathods of the same names.
